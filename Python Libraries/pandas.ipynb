# %%
import pandas as pd

# %%
a = pd.Series([34,68,34,21,92])
print(a)
print(type(a))
# Out:
# 0    34
# 1    68
# 2    34
# 3    21
# 4    92
# dtype: int64
# <class 'pandas.Series'>

# %%
marks = pd.Series([34,68,34,21,92],index=["Rahul","Jay","El","Sid","Vicky"])
print(marks)
# Out:
# Rahul    34
# Jay      68
# El       34
# Sid      21
# Vicky    92
# dtype: int64

# %%
print(marks["Rahul"])
print(marks.max())
print(marks.mean())
# Out:
# 34
# 92
# 49.8

# %%
students = {
    "Name" : ["Rahul","Vicky","Jay","Gaurav"],
    "Marks" : [84,78,96,84],
    "CGPA" : [9.5,7.5,8.6,9.2] 
}

# %%
df = pd.DataFrame(students)
print(df)
# Out:
#      Name  Marks  CGPA
# 0   Rahul     84   9.5
# 1   Vicky     78   7.5
# 2     Jay     96   8.6
# 3  Gaurav     84   9.2

# %%
print(df["Name"])
# Out:
# 0     Rahul
# 1     Vicky
# 2       Jay
# 3    Gaurav
# Name: Name, dtype: str

# %%
#loc #iloc
print(df)
# Out:
#      Name  Marks  CGPA
# 0   Rahul     84   9.5
# 1   Vicky     78   7.5
# 2     Jay     96   8.6
# 3  Gaurav     84   9.2

# %%
print(df.loc[0])
# Out:
# Name     Rahul
# Marks       84
# CGPA       9.5
# Name: 0, dtype: object

# %%
print(df.loc[0:2]) #inclusive
# Out:
#     Name  Marks  CGPA
# 0  Rahul     84   9.5
# 1  Vicky     78   7.5
# 2    Jay     96   8.6

# %%
print(df.loc[0:2,"Marks"]) #inclusive
# Out:
# 0    84
# 1    78
# 2    96
# Name: Marks, dtype: int64

# %%
print(df.iloc[0:2,2])
# Out:
# 0    9.5
# 1    7.5
# Name: CGPA, dtype: float64

# %%
df = pd.read_csv("students data.csv")

# %%
print(df.head())
# Out:
#            Name Branch  Marks  Attendance  CGPA       City  Gender  Backlogs
# 0    Ravi Kumar    ECE     88          92   8.5  Hyderabad    Male         0
# 1  Priya Sharma    CSE     92          88   9.0  Bangalore  Female         0
# 2   Arjun Reddy    ECE     74          78   7.8  Hyderabad    Male         1
# 3    Divya Nair    CSE     68          95   7.2    Chennai  Female         0
# 4     Kiran Rao   VLSI     95          85   9.4       Pune    Male         0

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        20 non-null     str
#  1   Branch      20 non-null     str
#  2   Marks       20 non-null     int64
#  3   Attendance  20 non-null     int64
#  4   CGPA        20 non-null     float64
#  5   City        20 non-null     str
#  6   Gender      20 non-null     str
#  7   Backlogs    20 non-null     int64
# dtypes: float64(1), int64(3), str(4)
# memory usage: 1.4 KB
# None

# %%
print(df.describe())
# Out:
#            Marks  Attendance       CGPA   Backlogs
# count  20.000000    20.00000  20.000000  20.000000
# mean   76.000000    82.00000   7.765000   0.600000
# std    14.607136    11.82326   1.117457   0.940325
# min    47.000000    58.00000   5.900000   0.000000
# 25%    66.500000    74.25000   7.025000   0.000000
# 50%    78.500000    86.00000   7.850000   0.000000
# 75%    88.000000    91.25000   8.550000   1.000000
# max    96.000000    96.00000   9.600000   3.000000

# %%
print(df.shape)
# Out:
# (20, 8)

# %%
print(df.columns)
# Out:
# Index(['Name', 'Branch', 'Marks', 'Attendance', 'CGPA', 'City', 'Gender',
#        'Backlogs'],
#       dtype='str')

# %%
print(df.head())
# Out:
#            Name Branch  Marks  Attendance  CGPA       City  Gender  Backlogs
# 0    Ravi Kumar    ECE     88          92   8.5  Hyderabad    Male         0
# 1  Priya Sharma    CSE     92          88   9.0  Bangalore  Female         0
# 2   Arjun Reddy    ECE     74          78   7.8  Hyderabad    Male         1
# 3    Divya Nair    CSE     68          95   7.2    Chennai  Female         0
# 4     Kiran Rao   VLSI     95          85   9.4       Pune    Male         0

# %%
print(df.loc[0:9,"Marks"])
# Out:
# 0    88
# 1    92
# 2    74
# 3    68
# 4    95
# 5    82
# 6    79
# 7    88
# 8    55
# 9    91
# Name: Marks, dtype: int64

# %%
print(df.head())
# Out:
#            Name Branch  Marks  Attendance  CGPA       City  Gender  Backlogs
# 0    Ravi Kumar    ECE     88          92   8.5  Hyderabad    Male         0
# 1  Priya Sharma    CSE     92          88   9.0  Bangalore  Female         0
# 2   Arjun Reddy    ECE     74          78   7.8  Hyderabad    Male         1
# 3    Divya Nair    CSE     68          95   7.2    Chennai  Female         0
# 4     Kiran Rao   VLSI     95          85   9.4       Pune    Male         0

# %%
print(df[df["Marks"]>=95])
# Out:
#           Name Branch  Marks  Attendance  CGPA     City  Gender  Backlogs
# 4    Kiran Rao   VLSI     95          85   9.4     Pune    Male         0
# 15  Ananya Roy    CSE     96          91   9.6  Kolkata  Female         0

# %%
print(df[df["City"]=="Bangalore"])
# Out:
#             Name Branch  Marks  Attendance  CGPA       City  Gender  Backlogs
# 1   Priya Sharma    CSE     92          88   9.0  Bangalore  Female         0
# 13    Tanvi Bhat    CSE     85          94   8.4  Bangalore  Female         0

# %%
print(df[(df["Branch"]=="ECE") & (df["City"]=="Hyderabad")])
# Out:
#           Name Branch  Marks  Attendance  CGPA       City Gender  Backlogs
# 0   Ravi Kumar    ECE     88          92   8.5  Hyderabad   Male         0
# 2  Arjun Reddy    ECE     74          78   7.8  Hyderabad   Male         1

# %%
cs = df[df["Branch"]=="CSE"]
print(cs)
print(len(cs))
# Out:
#             Name Branch  Marks  Attendance  CGPA       City  Gender  Backlogs
# 1   Priya Sharma    CSE     92          88   9.0  Bangalore  Female         0
# 3     Divya Nair    CSE     68          95   7.2    Chennai  Female         0
# 6    Rahul Singh    CSE     79          72   7.9      Delhi    Male         0
# 9   Lakshmi Devi    CSE     91          89   8.9  Hyderabad  Female         0
# 13    Tanvi Bhat    CSE     85          94   8.4  Bangalore  Female         0
# 15    Ananya Roy    CSE     96          91   9.6    Kolkata  Female         0
# 19  Swathi Reddy    CSE     83          93   8.2  Hyderabad  Female         0
# 7

# %%
print(cs["CGPA"].mean().round(2))
# Out:
# 8.46

# %%
b = df[(df["Branch"]=="ECE") | (df["Branch"]=="VLSI")]
print(b)
# Out:
#              Name Branch  Marks  Attendance  CGPA       City  Gender  Backlogs
# 0      Ravi Kumar    ECE     88          92   8.5  Hyderabad    Male         0
# 2     Arjun Reddy    ECE     74          78   7.8  Hyderabad    Male         1
# 4       Kiran Rao   VLSI     95          85   9.4       Pune    Male         0
# 5     Sneha Patil    ECE     82          90   8.1     Mumbai  Female         0
# 7      Meena Iyer   VLSI     88          96   8.7    Chennai  Female         0
# 10   Nikhil Joshi   VLSI     73          80   7.5       Pune    Male         1
# 12    Sameer Khan    ECE     47          60   5.9     Mumbai    Male         3
# 16    Deepak Nair   VLSI     62          70   6.5      Kochi    Male         2
# 17  Harini Suresh    ECE     78          87   7.7    Chennai  Female         0

# %%
print(b["CGPA"].mean().round(2))
# Out:
# 7.79

# %%
print(df.groupby("Branch")["CGPA"].mean().round(2))
# Out:
# Branch
# CSE     8.46
# ECE     7.60
# EEE     6.50
# VLSI    8.02
# Name: CGPA, dtype: float64

# %%
print(df.groupby("Branch")["Attendance"].mean().round(2))
# Out:
# Branch
# CSE     88.86
# ECE     81.40
# EEE     70.00
# VLSI    82.75
# Name: Attendance, dtype: float64

# %%
print(df.groupby("Branch")["Marks"].max().round(2))
# Out:
# Branch
# CSE     96
# ECE     88
# EEE     70
# VLSI    95
# Name: Marks, dtype: int64

# %%
print(df.sort_values("Marks").head())
# Out:
#             Name Branch  Marks  Attendance  CGPA     City  Gender  Backlogs
# 12   Sameer Khan    ECE     47          60   5.9   Mumbai    Male         3
# 18  Manish Gupta    EEE     53          58   6.1    Delhi    Male         2
# 8   Aakash Verma    EEE     55          65   6.0  Kolkata    Male         2
# 11   Pooja Menon    EEE     61          75   6.8    Kochi  Female         0
# 16   Deepak Nair   VLSI     62          70   6.5    Kochi    Male         2

# %%
print(df.sort_values("Marks",ascending=False).head(10))
# Out:
#             Name Branch  Marks  Attendance  CGPA       City  Gender  Backlogs
# 15    Ananya Roy    CSE     96          91   9.6    Kolkata  Female         0
# 4      Kiran Rao   VLSI     95          85   9.4       Pune    Male         0
# 1   Priya Sharma    CSE     92          88   9.0  Bangalore  Female         0
# 9   Lakshmi Devi    CSE     91          89   8.9  Hyderabad  Female         0
# 0     Ravi Kumar    ECE     88          92   8.5  Hyderabad    Male         0
# 7     Meena Iyer   VLSI     88          96   8.7    Chennai  Female         0
# 13    Tanvi Bhat    CSE     85          94   8.4  Bangalore  Female         0
# 19  Swathi Reddy    CSE     83          93   8.2  Hyderabad  Female         0
# 5    Sneha Patil    ECE     82          90   8.1     Mumbai  Female         0
# 6    Rahul Singh    CSE     79          72   7.9      Delhi    Male         0

# %%
cs = df[df["Branch"]=="CSE"]
print(cs)
# Out:
#             Name Branch  Marks  Attendance  CGPA       City  Gender  Backlogs
# 1   Priya Sharma    CSE     92          88   9.0  Bangalore  Female         0
# 3     Divya Nair    CSE     68          95   7.2    Chennai  Female         0
# 6    Rahul Singh    CSE     79          72   7.9      Delhi    Male         0
# 9   Lakshmi Devi    CSE     91          89   8.9  Hyderabad  Female         0
# 13    Tanvi Bhat    CSE     85          94   8.4  Bangalore  Female         0
# 15    Ananya Roy    CSE     96          91   9.6    Kolkata  Female         0
# 19  Swathi Reddy    CSE     83          93   8.2  Hyderabad  Female         0

# %%
top_scorers = cs.sort_values("Marks",ascending=False).head(3)
print(top_scorers)
# Out:
#             Name Branch  Marks  Attendance  CGPA       City  Gender  Backlogs
# 15    Ananya Roy    CSE     96          91   9.6    Kolkata  Female         0
# 1   Priya Sharma    CSE     92          88   9.0  Bangalore  Female         0
# 9   Lakshmi Devi    CSE     91          89   8.9  Hyderabad  Female         0

# %%
print(top_scorers.reset_index(drop=True))
# Out:
#            Name Branch  Marks  Attendance  CGPA       City  Gender  Backlogs
# 0    Ananya Roy    CSE     96          91   9.6    Kolkata  Female         0
# 1  Priya Sharma    CSE     92          88   9.0  Bangalore  Female         0
# 2  Lakshmi Devi    CSE     91          89   8.9  Hyderabad  Female         0

# %%
print(df.sort_values("CGPA",ascending=False).groupby("City").first())
# Out:
#                    Name Branch  Marks  Attendance  CGPA  Gender  Backlogs
# City
# Bangalore    Tanvi Bhat    CSE     85          94   8.4  Female         0
# Chennai      Divya Nair    CSE     68          95   7.2  Female         0
# Delhi      Manish Gupta    EEE     53          58   6.1    Male         2
# Hyderabad  Vijay Prasad    EEE     70          82   7.1    Male         1
# Kochi       Deepak Nair   VLSI     62          70   6.5    Male         2
# Kolkata    Aakash Verma    EEE     55          65   6.0    Male         2
# Mumbai      Sameer Khan    ECE     47          60   5.9    Male         3
# Pune       Nikhil Joshi   VLSI     73          80   7.5    Male         1

# %%
print(df.groupby("City")["Marks"].max())
# Out:
# City
# Bangalore    92
# Chennai      88
# Delhi        79
# Hyderabad    91
# Kochi        62
# Kolkata      96
# Mumbai       82
# Pune         95
# Name: Marks, dtype: int64

# %%
print(df.groupby("Branch")["CGPA"].agg(["max","mean","min"]))
# Out:
#         max      mean  min
# Branch
# CSE     9.6  8.457143  7.2
# ECE     8.5  7.600000  5.9
# EEE     7.1  6.500000  6.0
# VLSI    9.4  8.025000  6.5

# %%
print(df.groupby("Branch")["CGPA"].mean().round(2))
# Out:
# Branch
# CSE     8.46
# ECE     7.60
# EEE     6.50
# VLSI    8.02
# Name: CGPA, dtype: float64

# %%
avg = df.groupby("Branch")["CGPA"].mean().round(2)
avg.plot(kind="bar",figsize=(5,3))
# Out:
# <Axes: xlabel='Branch'>
